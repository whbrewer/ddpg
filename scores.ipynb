# %% [markdown]
# # plot scores

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

with open('scores.log') as fp:
    lines = fp.readlines()
    
lines = [line.rstrip() for line in lines]
# lines = [s.strip() for s in lines.splitlines()]

avg_scores = []
best_scores = []
for line in lines:
    try:
        episode, avg_score = line.split('\t')
        best_score = 0.0
    except:
        episode, avg_score, best_score = line.split('\t')

    avg_scores.append(float(avg_score))
    best_scores.append(float(best_score))

scores = avg_scores
print(len(scores))

fig = plt.figure()
ax = fig.add_subplot(211)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Avg Score')
plt.xlabel('Episode #')
plt.ylim(0, 2)

scores = best_scores
ax2 = fig.add_subplot(212)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Best Score')
plt.xlabel('Episode #')
plt.ylim(0, 5.2)

plt.show()
# Out:
# 1862
